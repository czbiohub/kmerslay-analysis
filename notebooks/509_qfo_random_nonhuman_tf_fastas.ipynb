# %%
from glob import iglob
import os

import pandas as pd
import screed
import seaborn as sns
from tqdm import tqdm

# %% [markdown]
# # Change to Quest for Orthologs 2019 data directory

# %%
cd ~/data_sm/kmer-hashing/quest-for-orthologs/data/2019/
# Out:
# /mnt/data_sm/olga/kmer-hashing/quest-for-orthologs/data/2019

# %%
ls -lha
# Out:
# total 2.7G
# drwxr-xr-x  5 olga root 4.0K Jan 17 07:54 ./
# drwxr-xr-x  3 olga root 4.0K Dec 25 17:48 ../
# drwxr-xr-x  5 olga czb  4.0K Dec 26 19:44 Archaea/
# drwxr-xr-x  5 olga czb   16K Dec 26 19:44 Bacteria/
# drwxr-xr-x 11 olga czb   32K Jan 17 07:52 Eukaryota/
# -rw-r--r--  1 olga czb  754K Jan 10 07:50 human_transcription_factors_with_uniprot_ids.csv
# -rw-r--r--  1 olga czb   68K Jan 10 07:50 human_transcription_factors_with_uniprot_ids.csv.gz
# -rw-r--r--  1 olga czb  133K Jan 10 07:50 human_transcription_factors_with_uniprot_ids.parquet
# -rw-r--r--  1 olga czb   14K Jan 17 07:54 human_transcription_factors_with_uniprot_ids_random_subset100.csv
# -rw-r--r--  1 olga czb  3.5K Jan 17 07:54 human_transcription_factors_with_uniprot_ids_random_subset100.csv.gz
# -rw-r--r--  1 olga czb   12K Jan 17 07:54 human_transcription_factors_with_uniprot_ids_random_subset100.parquet
# -rw-r--r--  1 olga czb   76K Jan 15 10:57 human_visual_transduction_with_uniprot_ids.csv
# -rw-r--r--  1 olga czb   19K Jan 15 10:57 human_visual_transduction_with_uniprot_ids.csv.gz
# -rw-r--r--  1 olga czb   28K Jan 15 10:57 human_visual_transduction_with_uniprot_ids.parquet
# -rw-r--r--  1 olga czb   64M Jan 10 07:43 opisthokont_not_human_transcription_factors_ensembl_compara.csv
# -rw-r--r--  1 olga czb   19M Jan 15 18:51 opisthokont_not_human_transcription_factors_ensembl_compara_merged_uniprot.csv.gz
# -rw-r--r--  1 olga czb   23M Jan 15 18:51 opisthokont_not_human_transcription_factors_ensembl_compara_merged_uniprot.parquet
# -rw-r--r--  1 olga czb   12M Jan 10 07:43 opisthokont_not_human_transcription_factors_ensembl_compara.parquet
# -rw-r--r--  1 olga czb  3.4M Jan 15 18:10 opisthokont_not_human_visual_system_ensembl_compara.csv
# -rw-r--r--  1 olga czb  431K Jan 15 18:10 opisthokont_not_human_visual_system_ensembl_compara.parquet
# -rw-r--r--  1 olga czb   17M Jan 15 18:49 opisthokont_not_human_visual_transduction_ensembl_compara_merged_uniprot.csv.gz
# -rw-r--r--  1 olga czb   21M Jan 15 18:50 opisthokont_not_human_visual_transduction_ensembl_compara_merged_uniprot.parquet
# -rw-r--r--  1 olga czb   661 Jan  8 17:33 qfo_human_vs_opisthokont_tfs.sh
# -rw-r--r--  1 olga czb  2.6G Dec 25 18:46 QfO_release_2019_04.tar.gz
# -rw-r--r--  1 olga czb   18K May 10  2019 README
# -rw-r--r--  1 olga czb   12K Jan  8 07:47 species_metadata.csv

# %%
ls Eukaryota/
# Out:
# human-protein-fastas/
# human-protein-fastas-concatenated/
# human-transcription-factor-fastas/
# human-transcription-factor-fastas-random-subset100/
# human-visual-transduction-fastas/
# not-human-protein-fastas/
# not-human-transcription-factor-fastas/
# not-human-visual-transduction-fastas/
# protein-fastas/
# UP000000437_7955_additional.fasta
# UP000000437_7955_DNA.fasta
# UP000000437_7955_DNA.miss
# UP000000437_7955.fasta
# UP000000437_7955_gcoord.xml
# UP000000437_7955.gene2acc
# UP000000437_7955.idmapping
# UP000000437_7955.xml
# UP000000539_9031_additional.fasta
# UP000000539_9031_DNA.fasta
# UP000000539_9031_DNA.miss
# UP000000539_9031.fasta
# UP000000539_9031_gcoord.xml
# UP000000539_9031.gene2acc
# UP000000539_9031.idmapping
# UP000000539_9031.xml
# UP000000542_5664_DNA.fasta
# UP000000542_5664.fasta
# UP000000542_5664.gene2acc
# UP000000542_5664.idmapping
# UP000000542_5664.xml
# UP000000559_237561_additional.fasta
# UP000000559_237561_DNA.fasta
# UP000000559_237561_DNA.miss
# UP000000559_237561.fasta
# UP000000559_237561.gene2acc
# UP000000559_237561.idmapping
# UP000000559_237561.xml
# UP000000561_237631_additional.fasta
# UP000000561_237631_DNA.fasta
# UP000000561_237631.fasta
# UP000000561_237631.gene2acc
# UP000000561_237631.idmapping
# UP000000561_237631.xml
# UP000000589_10090_additional.fasta
# UP000000589_10090_DNA.fasta
# UP000000589_10090_DNA.miss
# UP000000589_10090.fasta
# UP000000589_10090_gcoord.xml
# UP000000589_10090.gene2acc
# UP000000589_10090.idmapping
# UP000000589_10090.xml
# UP000000600_5888_DNA.fasta
# UP000000600_5888.fasta
# UP000000600_5888.gene2acc
# UP000000600_5888.idmapping
# UP000000600_5888.xml
# UP000000803_7227_additional.fasta
# UP000000803_7227_DNA.fasta
# UP000000803_7227.fasta
# UP000000803_7227.gene2acc
# UP000000803_7227.idmapping
# UP000000803_7227.xml
# UP000001038_8090_additional.fasta
# UP000001038_8090_DNA.fasta
# UP000001038_8090_DNA.miss
# UP000001038_8090.fasta
# UP000001038_8090_gcoord.xml
# UP000001038_8090.gene2acc
# UP000001038_8090.idmapping
# UP000001038_8090.xml
# UP000001055_321614_DNA.fasta
# UP000001055_321614.fasta
# UP000001055_321614.gene2acc
# UP000001055_321614.idmapping
# UP000001055_321614.xml
# UP000001300_284591_additional.fasta
# UP000001300_284591_DNA.fasta
# UP000001300_284591_DNA.miss
# UP000001300_284591.fasta
# UP000001300_284591.gene2acc
# UP000001300_284591.idmapping
# UP000001300_284591.xml
# UP000001312_665079_DNA.fasta
# UP000001312_665079.fasta
# UP000001312_665079.gene2acc
# UP000001312_665079.idmapping
# UP000001312_665079.xml
# UP000001357_81824_DNA.fasta
# UP000001357_81824.fasta
# UP000001357_81824.gene2acc
# UP000001357_81824.idmapping
# UP000001357_81824.xml
# UP000001449_35128_additional.fasta
# UP000001449_35128_DNA.fasta
# UP000001449_35128.fasta
# UP000001449_35128.gene2acc
# UP000001449_35128.idmapping
# UP000001449_35128.xml
# UP000001450_36329_additional.fasta
# UP000001450_36329_DNA.fasta
# UP000001450_36329_DNA.miss
# UP000001450_36329.fasta
# UP000001450_36329.gene2acc
# UP000001450_36329.idmapping
# UP000001450_36329.xml
# UP000001519_9595_additional.fasta
# UP000001519_9595_DNA.fasta
# UP000001519_9595_DNA.miss
# UP000001519_9595.fasta
# UP000001519_9595_gcoord.xml
# UP000001519_9595.gene2acc
# UP000001519_9595.idmapping
# UP000001519_9595.xml
# UP000001542_5722_DNA.fasta
# UP000001542_5722.fasta
# UP000001542_5722.gene2acc
# UP000001542_5722.idmapping
# UP000001542_5722.xml
# UP000001548_184922_DNA.fasta
# UP000001548_184922.fasta
# UP000001548_184922.gene2acc
# UP000001548_184922.idmapping
# UP000001548_184922.xml
# UP000001554_7739_additional.fasta
# UP000001554_7739_DNA.fasta
# UP000001554_7739_DNA.miss
# UP000001554_7739.fasta
# UP000001554_7739.gene2acc
# UP000001554_7739.idmapping
# UP000001554_7739.xml
# UP000001555_6945_DNA.fasta
# UP000001555_6945.fasta
# UP000001555_6945_gcoord.xml
# UP000001555_6945.gene2acc
# UP000001555_6945.idmapping
# UP000001555_6945.xml
# UP000001593_45351_additional.fasta
# UP000001593_45351_DNA.fasta
# UP000001593_45351.fasta
# UP000001593_45351.gene2acc
# UP000001593_45351.idmapping
# UP000001593_45351.xml
# UP000001805_367110_additional.fasta
# UP000001805_367110_DNA.fasta
# UP000001805_367110.fasta
# UP000001805_367110.gene2acc
# UP000001805_367110.idmapping
# UP000001805_367110.xml
# UP000001940_6239_additional.fasta
# UP000001940_6239_DNA.fasta
# UP000001940_6239_DNA.miss
# UP000001940_6239.fasta
# UP000001940_6239.gene2acc
# UP000001940_6239.idmapping
# UP000001940_6239.xml
# UP000002149_214684_additional.fasta
# UP000002149_214684_DNA.fasta
# UP000002149_214684_DNA.miss
# UP000002149_214684.fasta
# UP000002149_214684.gene2acc
# UP000002149_214684.idmapping
# UP000002149_214684.xml
# UP000002195_44689_additional.fasta
# UP000002195_44689_DNA.fasta
# UP000002195_44689_DNA.miss
# UP000002195_44689.fasta
# UP000002195_44689.gene2acc
# UP000002195_44689.idmapping
# UP000002195_44689.xml
# UP000002254_9615_additional.fasta
# UP000002254_9615_DNA.fasta
# UP000002254_9615_DNA.miss
# UP000002254_9615.fasta
# UP000002254_9615_gcoord.xml
# UP000002254_9615.gene2acc
# UP000002254_9615.idmapping
# UP000002254_9615.xml
# UP000002277_9598_additional.fasta
# UP000002277_9598_DNA.fasta
# UP000002277_9598_DNA.miss
# UP000002277_9598.fasta
# UP000002277_9598_gcoord.xml
# UP000002277_9598.gene2acc
# UP000002277_9598.idmapping
# UP000002277_9598.xml
# UP000002280_13616_additional.fasta
# UP000002280_13616_DNA.fasta
# UP000002280_13616_DNA.miss
# UP000002280_13616.fasta
# UP000002280_13616_gcoord.xml
# UP000002280_13616.gene2acc
# UP000002280_13616.idmapping
# UP000002280_13616.xml
# UP000002311_559292_additional.fasta
# UP000002311_559292_DNA.fasta
# UP000002311_559292_DNA.miss
# UP000002311_559292.fasta
# UP000002311_559292_gcoord.xml
# UP000002311_559292.gene2acc
# UP000002311_559292.idmapping
# UP000002311_559292.xml
# UP000002485_284812_additional.fasta
# UP000002485_284812_DNA.fasta
# UP000002485_284812_DNA.miss
# UP000002485_284812.fasta
# UP000002485_284812.gene2acc
# UP000002485_284812.idmapping
# UP000002485_284812.xml
# UP000002494_10116_additional.fasta
# UP000002494_10116_DNA.fasta
# UP000002494_10116_DNA.miss
# UP000002494_10116.fasta
# UP000002494_10116_gcoord.xml
# UP000002494_10116.gene2acc
# UP000002494_10116.idmapping
# UP000002494_10116.xml
# UP000002530_330879_DNA.fasta
# UP000002530_330879.fasta
# UP000002530_330879.gene2acc
# UP000002530_330879.idmapping
# UP000002530_330879.xml
# UP000005238_164328_DNA.fasta
# UP000005238_164328.fasta
# UP000005238_164328_gcoord.xml
# UP000005238_164328.gene2acc
# UP000005238_164328.idmapping
# UP000005238_164328.xml
# UP000005640_9606_additional.fasta
# UP000005640_9606_DNA.fasta
# UP000005640_9606_DNA.miss
# UP000005640_9606.fasta
# UP000005640_9606_gcoord.miss
# UP000005640_9606_gcoord.xml
# UP000005640_9606.gene2acc
# UP000005640_9606.idmapping
# UP000005640_9606.xml
# UP000006548_3702_additional.fasta
# UP000006548_3702_DNA.fasta
# UP000006548_3702_DNA.miss
# UP000006548_3702.fasta
# UP000006548_3702_gcoord.xml
# UP000006548_3702.gene2acc
# UP000006548_3702.idmapping
# UP000006548_3702.xml
# UP000006727_3218_additional.fasta
# UP000006727_3218_DNA.fasta
# UP000006727_3218.fasta
# UP000006727_3218.gene2acc
# UP000006727_3218.idmapping
# UP000006727_3218.xml
# UP000006906_3055_additional.fasta
# UP000006906_3055_DNA.fasta
# UP000006906_3055_DNA.miss
# UP000006906_3055.fasta
# UP000006906_3055.gene2acc
# UP000006906_3055.idmapping
# UP000006906_3055.xml
# UP000007062_7165_additional.fasta
# UP000007062_7165_DNA.fasta
# UP000007062_7165_DNA.miss
# UP000007062_7165.fasta
# UP000007062_7165_gcoord.xml
# UP000007062_7165.gene2acc
# UP000007062_7165.idmapping
# UP000007062_7165.xml
# UP000007241_684364_DNA.fasta
# UP000007241_684364.fasta
# UP000007241_684364.gene2acc
# UP000007241_684364.idmapping
# UP000007241_684364.xml
# UP000007266_7070_additional.fasta
# UP000007266_7070_DNA.fasta
# UP000007266_7070.fasta
# UP000007266_7070.gene2acc
# UP000007266_7070.idmapping
# UP000007266_7070.xml
# UP000007305_4577_additional.fasta
# UP000007305_4577_DNA.fasta
# UP000007305_4577_DNA.miss
# UP000007305_4577.fasta
# UP000007305_4577_gcoord.xml
# UP000007305_4577.gene2acc
# UP000007305_4577.idmapping
# UP000007305_4577.xml
# UP000008143_8364_additional.fasta
# UP000008143_8364_DNA.fasta
# UP000008143_8364_DNA.miss
# UP000008143_8364.fasta
# UP000008143_8364_gcoord.xml
# UP000008143_8364.gene2acc
# UP000008143_8364.idmapping
# UP000008143_8364.xml
# UP000008144_7719_additional.fasta
# UP000008144_7719_DNA.fasta
# UP000008144_7719.fasta
# UP000008144_7719_gcoord.xml
# UP000008144_7719.gene2acc
# UP000008144_7719.idmapping
# UP000008144_7719.xml
# UP000008783_418459_additional.fasta
# UP000008783_418459_DNA.fasta
# UP000008783_418459.fasta
# UP000008783_418459.gene2acc
# UP000008783_418459.idmapping
# UP000008783_418459.xml
# UP000009136_9913_additional.fasta
# UP000009136_9913_DNA.fasta
# UP000009136_9913_DNA.miss
# UP000009136_9913.fasta
# UP000009136_9913_gcoord.xml
# UP000009136_9913.gene2acc
# UP000009136_9913.idmapping
# UP000009136_9913.xml
# UP000015101_6412_DNA.fasta
# UP000015101_6412.fasta
# UP000015101_6412_gcoord.xml
# UP000015101_6412.gene2acc
# UP000015101_6412.idmapping
# UP000015101_6412.xml
# UP000018468_7918_additional.fasta
# UP000018468_7918_DNA.fasta
# UP000018468_7918.fasta
# UP000018468_7918_gcoord.xml
# UP000018468_7918.gene2acc
# UP000018468_7918.idmapping
# UP000018468_7918.xml
# UP000059680_39947_additional.fasta
# UP000059680_39947_DNA.fasta
# UP000059680_39947_DNA.miss
# UP000059680_39947.fasta
# UP000059680_39947.gene2acc
# UP000059680_39947.idmapping
# UP000059680_39947.xml

# %% [markdown]
# # Download orthology and transcription factor data

# %% [markdown]
# ## Read orthologous transcription factors

# %%
tfs_original = pd.read_csv('opisthokont_not_human_transcription_factors_ensembl_compara.csv')
print(tfs_original.shape)
tfs_original.head()
# Out:
# (343153, 16)
#      dn_ds    method_link_type       source__id  source__perc_id  \
# 0      NaN  ENSEMBL_PARALOGUES  ENSG00000267179          24.8792
# 1      NaN  ENSEMBL_PARALOGUES  ENSG00000267179          25.6039
# 2  0.35552  ENSEMBL_PARALOGUES  ENSG00000267179          26.3285
# 3  0.33996  ENSEMBL_PARALOGUES  ENSG00000267179          27.2947
# 4  0.18553  ENSEMBL_PARALOGUES  ENSG00000267179          20.2899
#
#    source__perc_pos source__protein_id source__species  source__taxon_id  \
# 0           37.1981    ENSP00000467286    homo_sapiens              9606
# 1           37.1981    ENSP00000467286    homo_sapiens              9606
# 2           38.1642    ENSP00000467286    homo_sapiens              9606
# 3           38.8889    ENSP00000467286    homo_sapiens              9606
# 4           25.8454    ENSP00000467286    homo_sapiens              9606
#
#         target__id  target__perc_id  target__perc_pos target__protein_id  \
# 0  ENSG00000175787          17.0813           25.5390    ENSP00000378792
# 1  ENSG00000187815          20.1521           29.2776    ENSP00000361791
# 2  ENSG00000172006          20.2602           29.3680    ENSP00000321132
# 3  ENSG00000188629          23.4927           33.4719    ENSP00000415070
# 4  ENSG00000270011          26.1682           33.3333    ENSP00000445323
#
#   target__species  target__taxon_id taxonomy_level           type
# 0    homo_sapiens              9606      Bilateria  other_paralog
# 1    homo_sapiens              9606      Bilateria  other_paralog
# 2    homo_sapiens              9606      Bilateria  other_paralog
# 3    homo_sapiens              9606      Bilateria  other_paralog
# 4    homo_sapiens              9606      Bilateria  other_paralog

# %% [markdown]
# ## Read random subset of TFs

# %%
tfs_random_subset = pd.read_csv('human_transcription_factors_with_uniprot_ids_random_subset100.csv')
print(tfs_random_subset.shape)
tfs_random_subset.head()
# Out:
# (100, 8)
#       Gene               ID               DBD  \
# 0  TFCP2L1  ENSG00000115112        Grainyhead
# 1     PREB  ENSG00000138073           Unknown
# 2     BPTF  ENSG00000171634           Unknown
# 3     MXI1  ENSG00000119950              bHLH
# 4    HNF4A  ENSG00000101076  Nuclear receptor
#
#   Motif status (Feb 2018)(Link to human TFs annotation)  \
# 0       Known motif – High-throughput in vitro [942]
# 1  Likely sequence specific TF according to liter...
# 2             Known motif – In vivo/Misc source [79]
# 3            Known motif – In vivo/Misc source [553]
# 4       Known motif – High-throughput in vitro [369]
#
#   IUPAC consensus (from selected PWM) uniprot_id  id_type            db_id
# 0                    DCYRGHNNNDDCYRGH     Q9NZI6  Ensembl  ENSG00000115112
# 1                                 NaN     H7C0W3  Ensembl  ENSG00000138073
# 2                        KKKNTTGTKKNV     J3KSY0  Ensembl  ENSG00000171634
# 3                            CCACGTGG     P50539  Ensembl  ENSG00000119950
# 4                      VRGGTCAAAGTCCA     F8WBS7  Ensembl  ENSG00000101076

# %% [markdown]
# ## Subset TF orthology to the random subset

# %%
tfs = tfs_original.query('source__id in @tfs_random_subset.db_id')
print(tfs.shape)
tfs.head()
# Out:
# (20586, 16)
#         dn_ds     method_link_type       source__id  source__perc_id  \
# 1406  0.15000  ENSEMBL_ORTHOLOGUES  ENSG00000101544          96.0212
# 1407  0.19118  ENSEMBL_ORTHOLOGUES  ENSG00000101544          99.2042
# 1408  0.08163  ENSEMBL_ORTHOLOGUES  ENSG00000101544          99.2927
# 1409  0.15306  ENSEMBL_ORTHOLOGUES  ENSG00000101544          98.2317
# 1410  0.24272  ENSEMBL_ORTHOLOGUES  ENSG00000101544          97.4359
#
#       source__perc_pos source__protein_id source__species  source__taxon_id  \
# 1406           96.1096    ENSP00000262198    homo_sapiens              9606
# 1407           99.2927    ENSP00000262198    homo_sapiens              9606
# 1408           99.4695    ENSP00000262198    homo_sapiens              9606
# 1409           98.6737    ENSP00000262198    homo_sapiens              9606
# 1410           98.3201    ENSP00000262198    homo_sapiens              9606
#
#               target__id  target__perc_id  target__perc_pos  \
# 1406  ENSGGOG00000003551          99.6330           99.7248
# 1407  ENSPPAG00000028735          99.7333           99.8222
# 1408  ENSPTRG00000010138          99.8222          100.0000
# 1409  ENSPPYG00000009265          98.7556           99.2000
# 1410  ENSNLEG00000008406          97.9556           98.8444
#
#       target__protein_id      target__species  target__taxon_id  \
# 1406  ENSGGOP00000003487      gorilla_gorilla              9595
# 1407  ENSPPAP00000011050         pan_paniscus              9597
# 1408  ENSPTRP00000017225      pan_troglodytes              9598
# 1409  ENSPPYP00000010399         pongo_abelii              9601
# 1410  ENSNLEP00000010232  nomascus_leucogenys             61853
#
#      taxonomy_level              type
# 1406      Homininae  ortholog_one2one
# 1407      Homininae  ortholog_one2one
# 1408      Homininae  ortholog_one2one
# 1409      Hominidae  ortholog_one2one
# 1410     Hominoidea  ortholog_one2one

# %% [markdown]
# # Go to Quest for Orthologs fastas

# %% [markdown]
# ## Read species metadata

# %%
species_metadata = pd.read_csv("species_metadata.csv")
print(species_metadata.shape)
species_metadata.head()
# Out:
# (78, 10)
#    proteome_id  tax_id oscode  n_main_fasta_canonical  \
# 0  UP000007062    7165  ANOGA                   12553
# 1  UP000000798  224324  AQUAE                    1553
# 2  UP000006548    3702  ARATH                   27475
# 3  UP000001570  224308  BACSU                    4260
# 4  UP000001414  226186  BACTN                    4782
#
#    n_additional_fasta_isoforms  n_gene2acc  \
# 0                          971       13619
# 1                            0        1557
# 2                        14123       41920
# 3                            7        4268
# 4                            0        4823
#
#                                         species_name  \
# 0       Anopheles gambiae (African malaria mosquito)
# 1                      Aquifex aeolicus (strain VF5)
# 2             Arabidopsis thaliana (Mouse-ear cress)
# 3                     Bacillus subtilis (strain 168)
# 4  Bacteroides thetaiotaomicron (strain ATCC 2914...
#
#    divergence_from_human_mya               scientific_name  \
# 0                      797.0             Anopheles gambiae
# 1                     4290.0              Aquifex aeolicus
# 2                     1496.0          Arabidopsis thaliana
# 3                     4290.0             Bacillus subtilis
# 4                     4290.0  Bacteroides thetaiotaomicron
#
#                                common_name_or_strain
# 0                           African malaria mosquito
# 1                                         strain VF5
# 2                                    Mouse-ear cress
# 3                                         strain 168
# 4  strain ATCC 29148 / DSM 2079 / NCTC 10582 / E5...

# %% [markdown]
# ### Subset to opisthokonts

# %%
# Estimated opisthokonta divergence time from http://timetree.org/
t = 1105
opisthokonts = species_metadata.query('divergence_from_human_mya <= @t')
print(opisthokonts.shape)
opisthokonts.head()
# Out:
# (35, 10)
#    proteome_id  tax_id oscode  n_main_fasta_canonical  \
# 0  UP000007062    7165  ANOGA                   12553
# 5  UP000007241  684364  BATDJ                    8610
# 6  UP000009136    9913  BOVIN                   23774
# 8  UP000001554    7739  BRAFL                   28542
# 9  UP000001940    6239  CAEEL                   19986
#
#    n_additional_fasta_isoforms  n_gene2acc  \
# 0                          971       13619
# 5                            0        8685
# 6                        14534       38438
# 8                            2       28608
# 9                         8309       28507
#
#                                         species_name  \
# 0       Anopheles gambiae (African malaria mosquito)
# 5  Batrachochytrium dendrobatidis (strain JAM81 /...
# 6                                Bos taurus (Bovine)
# 8  Branchiostoma floridae (Florida lancelet) (Amp...
# 9                             Caenorhabditis elegans
#
#    divergence_from_human_mya                 scientific_name  \
# 0                      797.0               Anopheles gambiae
# 5                     1105.0  Batrachochytrium dendrobatidis
# 6                       96.0                      Bos taurus
# 8                      684.0          Branchiostoma floridae
# 9                      797.0          Caenorhabditis elegans
#
#        common_name_or_strain
# 0   African malaria mosquito
# 5  strain JAM81 / FGSC 10211
# 6                     Bovine
# 8           Florida lancelet
# 9                        NaN

# %%
opisthokonts.query('scientific_name == "Homo sapiens"')
# Out:
#     proteome_id  tax_id oscode  n_main_fasta_canonical  \
# 32  UP000005640    9606  HUMAN                   21146
#
#     n_additional_fasta_isoforms  n_gene2acc          species_name  \
# 32                        74769       96332  Homo sapiens (Human)
#
#     divergence_from_human_mya scientific_name common_name_or_strain
# 32                        0.0    Homo sapiens                 Human

# %% [markdown]
# ## Read Gene Accession file
#
# ```
# Gene mapping files (*.gene2acc)
# ===============================
#
# Column 1 is a unique gene symbol that is chosen with the following order of
# preference from the annotation found in:
# 1) Model Organism Database (MOD)
# 2) Ensembl or Ensembl Genomes database
# 3) UniProt Ordered Locus Name (OLN)
# 4) UniProt Open Reading Frame (ORF)
# 5) UniProt Gene Name
# A dash symbol ('-') is used when the gene encoding a protein is unknown.
#
# Column 2 is the UniProtKB accession or isoform identifier for the given gene
# symbol. This column may have redundancy when two or more genes have identical
# translations.
#
# Column 3 is the gene symbol of the canonical accession used to represent the
# respective gene group and the first row of the sequence is the canonical one.
# ```

# %%
def read_gene2acc(gene2acc, names=['maybe_ensembl_id', 'uniprot_id', 'canonical_accession']):
    df = pd.read_csv(gene2acc, sep='\t', header=None, na_values='-', names=names)
    return df

gene2acc = read_gene2acc('Eukaryota/UP000005640_9606.gene2acc')
# gene2acc = pd.read_csv('Eukaryota/UP000005640_9606.gene2acc', sep='\t', header=None, na_values='-', names=columns)
print(gene2acc.shape)
gene2acc.head()
# Out:
# (96332, 3)
#   maybe_ensembl_id  uniprot_id canonical_accession
# 0              NaN  A0A075B7B6                 NaN
# 1              NaN  A0A075B714                 NaN
# 2              NaN  A0A075B713                 NaN
# 3              NaN  A0A075B712                 NaN
# 4              NaN  A0A075B711                 NaN

# %%
gene2acc.dropna()
# Out:
#        maybe_ensembl_id uniprot_id canonical_accession
# 600              ACOT7L     Q6ZUV0              ACOT7L
# 601              BARGIN     Q6ZT62              BARGIN
# 602              BARGIN   Q6ZT62-2              BARGIN
# 603                BCE1     O60756                BCE1
# 604            C1orf140     Q5VVS0            C1orf140
# ...                 ...        ...                 ...
# 96327  UNQ6190/PRO20217     Q6UXQ8    UNQ6190/PRO20217
# 96328  UNQ6493/PRO21345     Q6UXR8    UNQ6493/PRO21345
# 96329  UNQ6494/PRO21346     Q6UXR6    UNQ6494/PRO21346
# 96330  UNQ9165/PRO28630     Q6UXU0    UNQ9165/PRO28630
# 96331  UNQ9370/PRO34162     Q6UXP9    UNQ9370/PRO34162
#
# [95732 rows x 3 columns]

# %% [markdown]
# ## Read ID mapping file
#
# ```
# Database mapping files (*.idmapping)
# ====================================
#
# These files contain mappings from UniProtKB to other databases for each
# reference proteome.
# The format consists of three tab-separated columns:
#
# 1. UniProtKB accession
# 2. ID_type:
#    Database name as shown in UniProtKB cross-references and supported by the ID
#    mapping tool on the UniProt web site (http://www.uniprot.org/mapping)
# 3. ID:
#    Identifier in the cross-referenced database.
#
# ```

# %%
opisthokonts.head()
# Out:
#    proteome_id  tax_id oscode  n_main_fasta_canonical  \
# 0  UP000007062    7165  ANOGA                   12553
# 5  UP000007241  684364  BATDJ                    8610
# 6  UP000009136    9913  BOVIN                   23774
# 8  UP000001554    7739  BRAFL                   28542
# 9  UP000001940    6239  CAEEL                   19986
#
#    n_additional_fasta_isoforms  n_gene2acc  \
# 0                          971       13619
# 5                            0        8685
# 6                        14534       38438
# 8                            2       28608
# 9                         8309       28507
#
#                                         species_name  \
# 0       Anopheles gambiae (African malaria mosquito)
# 5  Batrachochytrium dendrobatidis (strain JAM81 /...
# 6                                Bos taurus (Bovine)
# 8  Branchiostoma floridae (Florida lancelet) (Amp...
# 9                             Caenorhabditis elegans
#
#    divergence_from_human_mya                 scientific_name  \
# 0                      797.0               Anopheles gambiae
# 5                     1105.0  Batrachochytrium dendrobatidis
# 6                       96.0                      Bos taurus
# 8                      684.0          Branchiostoma floridae
# 9                      797.0          Caenorhabditis elegans
#
#        common_name_or_strain
# 0   African malaria mosquito
# 5  strain JAM81 / FGSC 10211
# 6                     Bovine
# 8           Florida lancelet
# 9                        NaN

# %%
opisthokonts.query('proteome_id == "UP000000437"')
# Out:
#     proteome_id  tax_id oscode  n_main_fasta_canonical  \
# 17  UP000000437    7955  DANRE                   25939
#
#     n_additional_fasta_isoforms  n_gene2acc  \
# 17                        21219       47517
#
#                                    species_name  divergence_from_human_mya  \
# 17  Danio rerio (Zebrafish) (Brachydanio rerio)                      435.0
#
#    scientific_name common_name_or_strain
# 17     Danio rerio             Zebrafish

# %% [markdown]
# # Get ID Mapping for uniprot ids from ENSMBL

# %%
dfs = []

for filename in tqdm(sorted(iglob("Eukaryota/*.idmapping"))):
#     print(filename)
    basename = os.path.basename(filename)
    prefix = basename.split('.')[0]
    species_id, taxa_id = prefix.split("_")
#     print(f"{species_id=} {taxa_id=}")
    
    if species_id in opisthokonts.proteome_id.values:

        df = pd.read_csv(filename, sep='\t', header=None, names=['uniprot_id', 'id_type', 'db_id'])
        df['species_id'] = species_id
        df['taxa_id'] = species_id

        # Use only Ensembl data
#         df = df.query('id_type == "Ensembl"')
        print(df.shape)
        dfs.append(df)
    
id_mapping = pd.concat(dfs, ignore_index=True)
print(id_mapping.shape)
id_mapping.head()
# Out:
#   2%|▏         | 1/48 [00:00<00:32,  1.44it/s]
# (1036083, 5)
#   8%|▊         | 4/48 [00:01<00:18,  2.35it/s]
# (555421, 5)
# (149092, 5)
# (141961, 5)
#  12%|█▎        | 6/48 [00:02<00:19,  2.14it/s]
# (1631036, 5)
#  17%|█▋        | 8/48 [00:02<00:16,  2.46it/s]
# (809657, 5)
#  21%|██        | 10/48 [00:03<00:13,  2.92it/s]
# (575653, 5)
# (295804, 5)
#  25%|██▌       | 12/48 [00:03<00:10,  3.59it/s]
# (124774, 5)
# (277055, 5)
#  27%|██▋       | 13/48 [00:03<00:07,  4.39it/s]
# (181143, 5)
#  33%|███▎      | 16/48 [00:04<00:06,  4.63it/s]
# (839553, 5)
#  40%|███▉      | 19/48 [00:04<00:05,  5.33it/s]
# (565651, 5)
#  42%|████▏     | 20/48 [00:05<00:06,  4.24it/s]
# (549426, 5)
#  46%|████▌     | 22/48 [00:05<00:05,  4.49it/s]
# (518273, 5)
# (205999, 5)
#  48%|████▊     | 23/48 [00:05<00:07,  3.56it/s]
# (765068, 5)
# (146229, 5)
#  54%|█████▍    | 26/48 [00:06<00:05,  4.11it/s]
# (594466, 5)
#  56%|█████▋    | 27/48 [00:07<00:08,  2.53it/s]
# (1143307, 5)
#  60%|██████    | 29/48 [00:07<00:05,  3.32it/s]
# (424236, 5)
# (268306, 5)
# (149870, 5)
#  67%|██████▋   | 32/48 [00:08<00:04,  3.97it/s]
# (873723, 5)
# (214092, 5)
#  71%|███████   | 34/48 [00:09<00:05,  2.46it/s]
# (2668934, 5)
#  79%|███████▉  | 38/48 [00:10<00:03,  3.33it/s]
# (340838, 5)
# (151313, 5)
#  83%|████████▎ | 40/48 [00:10<00:02,  3.92it/s]
# (315939, 5)
#  90%|████████▉ | 43/48 [00:10<00:01,  4.43it/s]
# (637633, 5)
# (281658, 5)
#  92%|█████████▏| 44/48 [00:11<00:00,  4.62it/s]
# (307893, 5)
#  94%|█████████▍| 45/48 [00:11<00:00,  3.24it/s]
# (773011, 5)
#  96%|█████████▌| 46/48 [00:12<00:00,  3.11it/s]
# (561122, 5)
# 100%|██████████| 48/48 [00:12<00:00,  3.90it/s]
# (390075, 5)
# (19464294, 5)
#   uniprot_id       id_type        db_id   species_id      taxa_id
# 0     Q5PRD0  UniProtKB-ID  143BA_DANRE  UP000000437  UP000000437
# 1     Q5PRD0     Gene_Name       ywhaba  UP000000437  UP000000437
# 2     Q5PRD0  Gene_Synonym       ywhab1  UP000000437  UP000000437
# 3     Q5PRD0  Gene_ORFName   wu:fb80c08  UP000000437  UP000000437
# 4     Q5PRD0            GI     82592598  UP000000437  UP000000437

# %% [markdown]
# # Merge id mapping with ensembl compara tfs

# %%
tfs.tail()
# Out:
#         dn_ds     method_link_type       source__id  source__perc_id  \
# 340606    NaN  ENSEMBL_ORTHOLOGUES  ENSG00000140265          79.8122
# 340607    NaN  ENSEMBL_ORTHOLOGUES  ENSG00000140265          78.1690
# 340608    NaN  ENSEMBL_ORTHOLOGUES  ENSG00000140265          44.6009
# 340609    NaN  ENSEMBL_ORTHOLOGUES  ENSG00000140265          34.7418
# 340610    NaN  ENSEMBL_ORTHOLOGUES  ENSG00000140265          12.0892
#
#         source__perc_pos source__protein_id source__species  source__taxon_id  \
# 340606           87.0892    ENSP00000380174    homo_sapiens              9606
# 340607           87.2066    ENSP00000380174    homo_sapiens              9606
# 340608           48.7089    ENSP00000380174    homo_sapiens              9606
# 340609           41.6667    ENSP00000380174    homo_sapiens              9606
# 340610           22.8873    ENSP00000380174    homo_sapiens              9606
#
#                 target__id  target__perc_id  target__perc_pos  \
# 340606  ENSPCIG00000018336          78.5219           85.6813
# 340607  ENSSHAG00000012821          76.7281           85.5991
# 340608  ENSMODG00000047609          82.2511           89.8268
# 340609  ENSOANG00000010234          55.6391           66.7293
# 340610  ENSGALG00000046739          17.5768           33.2765
#
#         target__protein_id           target__species  target__taxon_id  \
# 340606  ENSPCIP00000024306    phascolarctos_cinereus             38626
# 340607  ENSSHAP00000015023      sarcophilus_harrisii              9305
# 340608  ENSMODP00000047480     monodelphis_domestica             13616
# 340609  ENSOANP00000016232  ornithorhynchus_anatinus              9258
# 340610  ENSGALP00000069629             gallus_gallus              9031
#
#        taxonomy_level               type
# 340606         Theria   ortholog_one2one
# 340607         Theria   ortholog_one2one
# 340608         Theria  ortholog_one2many
# 340609       Mammalia   ortholog_one2one
# 340610        Amniota   ortholog_one2one

# %%
id_mapping_for_merging = id_mapping.copy()
id_mapping_for_merging.columns = "target__" + id_mapping_for_merging.columns
id_mapping_for_merging.head()
# Out:
#   target__uniprot_id target__id_type target__db_id target__species_id  \
# 0             Q5PRD0    UniProtKB-ID   143BA_DANRE        UP000000437
# 1             Q5PRD0       Gene_Name        ywhaba        UP000000437
# 2             Q5PRD0    Gene_Synonym        ywhab1        UP000000437
# 3             Q5PRD0    Gene_ORFName    wu:fb80c08        UP000000437
# 4             Q5PRD0              GI      82592598        UP000000437
#
#   target__taxa_id
# 0     UP000000437
# 1     UP000000437
# 2     UP000000437
# 3     UP000000437
# 4     UP000000437

# %%
tfs.shape
# Out:
# (20586, 16)

# %%
# %%time

tfs_uniprot_merge_proteins = tfs.merge(id_mapping_for_merging, left_on='target__protein_id', right_on='target__db_id')
print(tfs_uniprot_merge_proteins.shape)
tfs_uniprot_merge_proteins.head()
# Out:
# (3105, 21)
# CPU times: user 11.3 s, sys: 460 ms, total: 11.7 s
# Wall time: 11.7 s
#      dn_ds     method_link_type       source__id  source__perc_id  \
# 0  0.15000  ENSEMBL_ORTHOLOGUES  ENSG00000101544          96.0212
# 1  0.08163  ENSEMBL_ORTHOLOGUES  ENSG00000101544          99.2927
# 2  0.34381  ENSEMBL_ORTHOLOGUES  ENSG00000101544          58.0018
# 3  0.13859  ENSEMBL_ORTHOLOGUES  ENSG00000101544          78.7798
# 4  0.15195  ENSEMBL_ORTHOLOGUES  ENSG00000101544          80.1061
#
#    source__perc_pos source__protein_id source__species  source__taxon_id  \
# 0           96.1096    ENSP00000262198    homo_sapiens              9606
# 1           99.4695    ENSP00000262198    homo_sapiens              9606
# 2           71.0875    ENSP00000262198    homo_sapiens              9606
# 3           85.9416    ENSP00000262198    homo_sapiens              9606
# 4           87.0911    ENSP00000262198    homo_sapiens              9606
#
#            target__id  target__perc_id  ...  target__protein_id  \
# 0  ENSGGOG00000003551          99.6330  ...  ENSGGOP00000003487
# 1  ENSPTRG00000010138          99.8222  ...  ENSPTRP00000017225
# 2  ENSRNOG00000053843          57.1429  ...  ENSRNOP00000073516
# 3  ENSRNOG00000053370          73.8194  ...  ENSRNOP00000068569
# 4  ENSMUSG00000053950          77.7682  ...  ENSMUSP00000068560
#
#      target__species target__taxon_id    taxonomy_level               type  \
# 0    gorilla_gorilla             9595         Homininae   ortholog_one2one
# 1    pan_troglodytes             9598         Homininae   ortholog_one2one
# 2  rattus_norvegicus            10116  Euarchontoglires  ortholog_one2many
# 3  rattus_norvegicus            10116  Euarchontoglires  ortholog_one2many
# 4       mus_musculus            10090  Euarchontoglires   ortholog_one2one
#
#   target__uniprot_id target__id_type       target__db_id target__species_id  \
# 0             G3QLW5     Ensembl_PRO  ENSGGOP00000003487        UP000001519
# 1             H2QER5     Ensembl_PRO  ENSPTRP00000017225        UP000002277
# 2         A0A0G2K5Q5     Ensembl_PRO  ENSRNOP00000073516        UP000002494
# 3         A0A0G2JT49     Ensembl_PRO  ENSRNOP00000068569        UP000002494
# 4             Q8CHC8     Ensembl_PRO  ENSMUSP00000068560        UP000000589
#
#   target__taxa_id
# 0     UP000001519
# 1     UP000002277
# 2     UP000002494
# 3     UP000002494
# 4     UP000000589
#
# [5 rows x 21 columns]

# %%
# %%time

tfs_uniprot_merge_genes = tfs.merge(id_mapping_for_merging, left_on='target__id', right_on='target__db_id')
print(tfs_uniprot_merge_genes.shape)
tfs_uniprot_merge_genes.head()
# Out:
# (13846, 21)
# CPU times: user 10.7 s, sys: 418 ms, total: 11.1 s
# Wall time: 11.1 s
#      dn_ds     method_link_type       source__id  source__perc_id  \
# 0  0.15000  ENSEMBL_ORTHOLOGUES  ENSG00000101544          96.0212
# 1  0.15000  ENSEMBL_ORTHOLOGUES  ENSG00000101544          96.0212
# 2  0.08163  ENSEMBL_ORTHOLOGUES  ENSG00000101544          99.2927
# 3  0.34381  ENSEMBL_ORTHOLOGUES  ENSG00000101544          58.0018
# 4  0.13859  ENSEMBL_ORTHOLOGUES  ENSG00000101544          78.7798
#
#    source__perc_pos source__protein_id source__species  source__taxon_id  \
# 0           96.1096    ENSP00000262198    homo_sapiens              9606
# 1           96.1096    ENSP00000262198    homo_sapiens              9606
# 2           99.4695    ENSP00000262198    homo_sapiens              9606
# 3           71.0875    ENSP00000262198    homo_sapiens              9606
# 4           85.9416    ENSP00000262198    homo_sapiens              9606
#
#            target__id  target__perc_id  ...  target__protein_id  \
# 0  ENSGGOG00000003551          99.6330  ...  ENSGGOP00000003487
# 1  ENSGGOG00000003551          99.6330  ...  ENSGGOP00000003487
# 2  ENSPTRG00000010138          99.8222  ...  ENSPTRP00000017225
# 3  ENSRNOG00000053843          57.1429  ...  ENSRNOP00000073516
# 4  ENSRNOG00000053370          73.8194  ...  ENSRNOP00000068569
#
#      target__species target__taxon_id    taxonomy_level               type  \
# 0    gorilla_gorilla             9595         Homininae   ortholog_one2one
# 1    gorilla_gorilla             9595         Homininae   ortholog_one2one
# 2    pan_troglodytes             9598         Homininae   ortholog_one2one
# 3  rattus_norvegicus            10116  Euarchontoglires  ortholog_one2many
# 4  rattus_norvegicus            10116  Euarchontoglires  ortholog_one2many
#
#   target__uniprot_id target__id_type       target__db_id target__species_id  \
# 0         A0A2I2ZMG9         Ensembl  ENSGGOG00000003551        UP000001519
# 1             G3QLW5         Ensembl  ENSGGOG00000003551        UP000001519
# 2             H2QER5         Ensembl  ENSPTRG00000010138        UP000002277
# 3         A0A0G2K5Q5         Ensembl  ENSRNOG00000053843        UP000002494
# 4         A0A0G2JT49         Ensembl  ENSRNOG00000053370        UP000002494
#
#   target__taxa_id
# 0     UP000001519
# 1     UP000001519
# 2     UP000002277
# 3     UP000002494
# 4     UP000002494
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Add human uniprot ids

# %%
human_id_mapping = pd.read_csv('Eukaryota/UP000005640_9606.idmapping', sep='\t', header=None, names=['uniprot_id', 'id_type', 'db_id'])
human_id_mapping.columns = 'source__' + human_id_mapping.columns
print(human_id_mapping.shape)
human_id_mapping.head()
# Out:
# (2668934, 3)
#   source__uniprot_id source__id_type    source__db_id
# 0           P62258-2         UniParc    UPI00001E6021
# 1           P62258-2     Ensembl_TRS  ENST00000571732
# 2           P62258-2     Ensembl_PRO  ENSP00000461762
# 3           P62258-2     Ensembl_TRS  ENST00000616643
# 4           P62258-2     Ensembl_PRO  ENSP00000481059

# %%
# %%time 
tfs_uniprot_merge_proteins_with_human = tfs_uniprot_merge_proteins.merge(
    human_id_mapping, left_on='source__protein_id', right_on='source__db_id', how='outer')
tfs_uniprot_merge_proteins_with_human.columns = tfs_uniprot_merge_proteins_with_human.columns.str.replace("source__", 'human__')
print(tfs_uniprot_merge_proteins_with_human.shape)
tfs_uniprot_merge_proteins_with_human.query('type == "ortholog_one2one"').head()
# Out:
# (2671985, 24)
# CPU times: user 2.03 s, sys: 340 ms, total: 2.37 s
# Wall time: 2.36 s
#      dn_ds     method_link_type        human__id  human__perc_id  \
# 0  0.15000  ENSEMBL_ORTHOLOGUES  ENSG00000101544         96.0212
# 1  0.08163  ENSEMBL_ORTHOLOGUES  ENSG00000101544         99.2927
# 4  0.15195  ENSEMBL_ORTHOLOGUES  ENSG00000101544         80.1061
# 5  0.13911  ENSEMBL_ORTHOLOGUES  ENSG00000101544         86.2069
# 6  0.13181  ENSEMBL_ORTHOLOGUES  ENSG00000101544         86.0301
#
#    human__perc_pos human__protein_id human__species  human__taxon_id  \
# 0          96.1096   ENSP00000262198   homo_sapiens           9606.0
# 1          99.4695   ENSP00000262198   homo_sapiens           9606.0
# 4          87.0911   ENSP00000262198   homo_sapiens           9606.0
# 5          90.8046   ENSP00000262198   homo_sapiens           9606.0
# 6          91.1583   ENSP00000262198   homo_sapiens           9606.0
#
#            target__id  target__perc_id  ...    taxonomy_level  \
# 0  ENSGGOG00000003551          99.6330  ...         Homininae
# 1  ENSPTRG00000010138          99.8222  ...         Homininae
# 4  ENSMUSG00000053950          77.7682  ...  Euarchontoglires
# 5  ENSCAFG00000000007          85.9788  ...     Boreoeutheria
# 6  ENSBTAG00000005916          84.5352  ...     Boreoeutheria
#
#                type target__uniprot_id  target__id_type       target__db_id  \
# 0  ortholog_one2one             G3QLW5      Ensembl_PRO  ENSGGOP00000003487
# 1  ortholog_one2one             H2QER5      Ensembl_PRO  ENSPTRP00000017225
# 4  ortholog_one2one             Q8CHC8      Ensembl_PRO  ENSMUSP00000068560
# 5  ortholog_one2one             F1PJN7      Ensembl_PRO  ENSCAFP00000000007
# 6  ortholog_one2one         A0A3S5ZPP3      Ensembl_PRO  ENSBTAP00000007769
#
#   target__species_id target__taxa_id human__uniprot_id human__id_type  \
# 0        UP000001519     UP000001519            Q6IQ32    Ensembl_PRO
# 1        UP000002277     UP000002277            Q6IQ32    Ensembl_PRO
# 4        UP000000589     UP000000589            Q6IQ32    Ensembl_PRO
# 5        UP000002254     UP000002254            Q6IQ32    Ensembl_PRO
# 6        UP000009136     UP000009136            Q6IQ32    Ensembl_PRO
#
#       human__db_id
# 0  ENSP00000262198
# 1  ENSP00000262198
# 4  ENSP00000262198
# 5  ENSP00000262198
# 6  ENSP00000262198
#
# [5 rows x 24 columns]

# %%
tfs_uniprot_merge_proteins_with_human.type.value_counts()
# Out:
# other_paralog             1893
# ortholog_one2one           707
# ortholog_many2many         233
# ortholog_one2many          184
# within_species_paralog      86
# alt_allele                   2
# Name: type, dtype: int64

# %% [markdown]
# ## Write merged TFs to disk

# %%
pwd
# Out:
# '/mnt/data_sm/olga/kmer-hashing/quest-for-orthologs/data/2019'

# %%
# %time tfs_uniprot_merge_proteins_with_human.to_csv('opisthokont_not_human_transcription_factors_ensembl_compara_merged_uniprot_random_subset100.csv.gz', index=False)
# %time tfs_uniprot_merge_proteins_with_human.to_parquet('opisthokont_not_human_transcription_factors_ensembl_compara_merged_uniprot_random_subset100.parquet', index=False)
# Out:
# CPU times: user 27.5 s, sys: 53 ms, total: 27.6 s
# Wall time: 27.8 s
# CPU times: user 2.36 s, sys: 134 ms, total: 2.5 s
# Wall time: 2.64 s

# %% [markdown]
# ## Make set variable for quick membership evalution

# %%
tf_orthologs = set(tfs_uniprot_merge_proteins_with_human.target__uniprot_id)

# %% [markdown]
# ### Prove that the set `tf_orthologs` is faster

# %%
# %timeit 'Q7Z761' in tf_orthologs
# Out:
# 26.5 ns ± 0.024 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit 'Q7Z761' in tfs_uniprot_merge_proteins_with_human.target__uniprot_id
# Out:
# 7.62 µs ± 35.7 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# #### Yep, sets are 3 orders of magnitude faster!

# %% [markdown]
# # Read non-human proteins and subset if they are an ortholog of a TF

# %% [markdown]
# ## Make outdir

# %%
ls Eukaryota
# Out:
# human-protein-fastas/
# human-protein-fastas-concatenated/
# human-transcription-factor-fastas/
# human-transcription-factor-fastas-random-subset100/
# human-visual-transduction-fastas/
# not-human-protein-fastas/
# not-human-transcription-factor-fastas/
# not-human-visual-transduction-fastas/
# protein-fastas/
# UP000000437_7955_additional.fasta
# UP000000437_7955_DNA.fasta
# UP000000437_7955_DNA.miss
# UP000000437_7955.fasta
# UP000000437_7955_gcoord.xml
# UP000000437_7955.gene2acc
# UP000000437_7955.idmapping
# UP000000437_7955.xml
# UP000000539_9031_additional.fasta
# UP000000539_9031_DNA.fasta
# UP000000539_9031_DNA.miss
# UP000000539_9031.fasta
# UP000000539_9031_gcoord.xml
# UP000000539_9031.gene2acc
# UP000000539_9031.idmapping
# UP000000539_9031.xml
# UP000000542_5664_DNA.fasta
# UP000000542_5664.fasta
# UP000000542_5664.gene2acc
# UP000000542_5664.idmapping
# UP000000542_5664.xml
# UP000000559_237561_additional.fasta
# UP000000559_237561_DNA.fasta
# UP000000559_237561_DNA.miss
# UP000000559_237561.fasta
# UP000000559_237561.gene2acc
# UP000000559_237561.idmapping
# UP000000559_237561.xml
# UP000000561_237631_additional.fasta
# UP000000561_237631_DNA.fasta
# UP000000561_237631.fasta
# UP000000561_237631.gene2acc
# UP000000561_237631.idmapping
# UP000000561_237631.xml
# UP000000589_10090_additional.fasta
# UP000000589_10090_DNA.fasta
# UP000000589_10090_DNA.miss
# UP000000589_10090.fasta
# UP000000589_10090_gcoord.xml
# UP000000589_10090.gene2acc
# UP000000589_10090.idmapping
# UP000000589_10090.xml
# UP000000600_5888_DNA.fasta
# UP000000600_5888.fasta
# UP000000600_5888.gene2acc
# UP000000600_5888.idmapping
# UP000000600_5888.xml
# UP000000803_7227_additional.fasta
# UP000000803_7227_DNA.fasta
# UP000000803_7227.fasta
# UP000000803_7227.gene2acc
# UP000000803_7227.idmapping
# UP000000803_7227.xml
# UP000001038_8090_additional.fasta
# UP000001038_8090_DNA.fasta
# UP000001038_8090_DNA.miss
# UP000001038_8090.fasta
# UP000001038_8090_gcoord.xml
# UP000001038_8090.gene2acc
# UP000001038_8090.idmapping
# UP000001038_8090.xml
# UP000001055_321614_DNA.fasta
# UP000001055_321614.fasta
# UP000001055_321614.gene2acc
# UP000001055_321614.idmapping
# UP000001055_321614.xml
# UP000001300_284591_additional.fasta
# UP000001300_284591_DNA.fasta
# UP000001300_284591_DNA.miss
# UP000001300_284591.fasta
# UP000001300_284591.gene2acc
# UP000001300_284591.idmapping
# UP000001300_284591.xml
# UP000001312_665079_DNA.fasta
# UP000001312_665079.fasta
# UP000001312_665079.gene2acc
# UP000001312_665079.idmapping
# UP000001312_665079.xml
# UP000001357_81824_DNA.fasta
# UP000001357_81824.fasta
# UP000001357_81824.gene2acc
# UP000001357_81824.idmapping
# UP000001357_81824.xml
# UP000001449_35128_additional.fasta
# UP000001449_35128_DNA.fasta
# UP000001449_35128.fasta
# UP000001449_35128.gene2acc
# UP000001449_35128.idmapping
# UP000001449_35128.xml
# UP000001450_36329_additional.fasta
# UP000001450_36329_DNA.fasta
# UP000001450_36329_DNA.miss
# UP000001450_36329.fasta
# UP000001450_36329.gene2acc
# UP000001450_36329.idmapping
# UP000001450_36329.xml
# UP000001519_9595_additional.fasta
# UP000001519_9595_DNA.fasta
# UP000001519_9595_DNA.miss
# UP000001519_9595.fasta
# UP000001519_9595_gcoord.xml
# UP000001519_9595.gene2acc
# UP000001519_9595.idmapping
# UP000001519_9595.xml
# UP000001542_5722_DNA.fasta
# UP000001542_5722.fasta
# UP000001542_5722.gene2acc
# UP000001542_5722.idmapping
# UP000001542_5722.xml
# UP000001548_184922_DNA.fasta
# UP000001548_184922.fasta
# UP000001548_184922.gene2acc
# UP000001548_184922.idmapping
# UP000001548_184922.xml
# UP000001554_7739_additional.fasta
# UP000001554_7739_DNA.fasta
# UP000001554_7739_DNA.miss
# UP000001554_7739.fasta
# UP000001554_7739.gene2acc
# UP000001554_7739.idmapping
# UP000001554_7739.xml
# UP000001555_6945_DNA.fasta
# UP000001555_6945.fasta
# UP000001555_6945_gcoord.xml
# UP000001555_6945.gene2acc
# UP000001555_6945.idmapping
# UP000001555_6945.xml
# UP000001593_45351_additional.fasta
# UP000001593_45351_DNA.fasta
# UP000001593_45351.fasta
# UP000001593_45351.gene2acc
# UP000001593_45351.idmapping
# UP000001593_45351.xml
# UP000001805_367110_additional.fasta
# UP000001805_367110_DNA.fasta
# UP000001805_367110.fasta
# UP000001805_367110.gene2acc
# UP000001805_367110.idmapping
# UP000001805_367110.xml
# UP000001940_6239_additional.fasta
# UP000001940_6239_DNA.fasta
# UP000001940_6239_DNA.miss
# UP000001940_6239.fasta
# UP000001940_6239.gene2acc
# UP000001940_6239.idmapping
# UP000001940_6239.xml
# UP000002149_214684_additional.fasta
# UP000002149_214684_DNA.fasta
# UP000002149_214684_DNA.miss
# UP000002149_214684.fasta
# UP000002149_214684.gene2acc
# UP000002149_214684.idmapping
# UP000002149_214684.xml
# UP000002195_44689_additional.fasta
# UP000002195_44689_DNA.fasta
# UP000002195_44689_DNA.miss
# UP000002195_44689.fasta
# UP000002195_44689.gene2acc
# UP000002195_44689.idmapping
# UP000002195_44689.xml
# UP000002254_9615_additional.fasta
# UP000002254_9615_DNA.fasta
# UP000002254_9615_DNA.miss
# UP000002254_9615.fasta
# UP000002254_9615_gcoord.xml
# UP000002254_9615.gene2acc
# UP000002254_9615.idmapping
# UP000002254_9615.xml
# UP000002277_9598_additional.fasta
# UP000002277_9598_DNA.fasta
# UP000002277_9598_DNA.miss
# UP000002277_9598.fasta
# UP000002277_9598_gcoord.xml
# UP000002277_9598.gene2acc
# UP000002277_9598.idmapping
# UP000002277_9598.xml
# UP000002280_13616_additional.fasta
# UP000002280_13616_DNA.fasta
# UP000002280_13616_DNA.miss
# UP000002280_13616.fasta
# UP000002280_13616_gcoord.xml
# UP000002280_13616.gene2acc
# UP000002280_13616.idmapping
# UP000002280_13616.xml
# UP000002311_559292_additional.fasta
# UP000002311_559292_DNA.fasta
# UP000002311_559292_DNA.miss
# UP000002311_559292.fasta
# UP000002311_559292_gcoord.xml
# UP000002311_559292.gene2acc
# UP000002311_559292.idmapping
# UP000002311_559292.xml
# UP000002485_284812_additional.fasta
# UP000002485_284812_DNA.fasta
# UP000002485_284812_DNA.miss
# UP000002485_284812.fasta
# UP000002485_284812.gene2acc
# UP000002485_284812.idmapping
# UP000002485_284812.xml
# UP000002494_10116_additional.fasta
# UP000002494_10116_DNA.fasta
# UP000002494_10116_DNA.miss
# UP000002494_10116.fasta
# UP000002494_10116_gcoord.xml
# UP000002494_10116.gene2acc
# UP000002494_10116.idmapping
# UP000002494_10116.xml
# UP000002530_330879_DNA.fasta
# UP000002530_330879.fasta
# UP000002530_330879.gene2acc
# UP000002530_330879.idmapping
# UP000002530_330879.xml
# UP000005238_164328_DNA.fasta
# UP000005238_164328.fasta
# UP000005238_164328_gcoord.xml
# UP000005238_164328.gene2acc
# UP000005238_164328.idmapping
# UP000005238_164328.xml
# UP000005640_9606_additional.fasta
# UP000005640_9606_DNA.fasta
# UP000005640_9606_DNA.miss
# UP000005640_9606.fasta
# UP000005640_9606_gcoord.miss
# UP000005640_9606_gcoord.xml
# UP000005640_9606.gene2acc
# UP000005640_9606.idmapping
# UP000005640_9606.xml
# UP000006548_3702_additional.fasta
# UP000006548_3702_DNA.fasta
# UP000006548_3702_DNA.miss
# UP000006548_3702.fasta
# UP000006548_3702_gcoord.xml
# UP000006548_3702.gene2acc
# UP000006548_3702.idmapping
# UP000006548_3702.xml
# UP000006727_3218_additional.fasta
# UP000006727_3218_DNA.fasta
# UP000006727_3218.fasta
# UP000006727_3218.gene2acc
# UP000006727_3218.idmapping
# UP000006727_3218.xml
# UP000006906_3055_additional.fasta
# UP000006906_3055_DNA.fasta
# UP000006906_3055_DNA.miss
# UP000006906_3055.fasta
# UP000006906_3055.gene2acc
# UP000006906_3055.idmapping
# UP000006906_3055.xml
# UP000007062_7165_additional.fasta
# UP000007062_7165_DNA.fasta
# UP000007062_7165_DNA.miss
# UP000007062_7165.fasta
# UP000007062_7165_gcoord.xml
# UP000007062_7165.gene2acc
# UP000007062_7165.idmapping
# UP000007062_7165.xml
# UP000007241_684364_DNA.fasta
# UP000007241_684364.fasta
# UP000007241_684364.gene2acc
# UP000007241_684364.idmapping
# UP000007241_684364.xml
# UP000007266_7070_additional.fasta
# UP000007266_7070_DNA.fasta
# UP000007266_7070.fasta
# UP000007266_7070.gene2acc
# UP000007266_7070.idmapping
# UP000007266_7070.xml
# UP000007305_4577_additional.fasta
# UP000007305_4577_DNA.fasta
# UP000007305_4577_DNA.miss
# UP000007305_4577.fasta
# UP000007305_4577_gcoord.xml
# UP000007305_4577.gene2acc
# UP000007305_4577.idmapping
# UP000007305_4577.xml
# UP000008143_8364_additional.fasta
# UP000008143_8364_DNA.fasta
# UP000008143_8364_DNA.miss
# UP000008143_8364.fasta
# UP000008143_8364_gcoord.xml
# UP000008143_8364.gene2acc
# UP000008143_8364.idmapping
# UP000008143_8364.xml
# UP000008144_7719_additional.fasta
# UP000008144_7719_DNA.fasta
# UP000008144_7719.fasta
# UP000008144_7719_gcoord.xml
# UP000008144_7719.gene2acc
# UP000008144_7719.idmapping
# UP000008144_7719.xml
# UP000008783_418459_additional.fasta
# UP000008783_418459_DNA.fasta
# UP000008783_418459.fasta
# UP000008783_418459.gene2acc
# UP000008783_418459.idmapping
# UP000008783_418459.xml
# UP000009136_9913_additional.fasta
# UP000009136_9913_DNA.fasta
# UP000009136_9913_DNA.miss
# UP000009136_9913.fasta
# UP000009136_9913_gcoord.xml
# UP000009136_9913.gene2acc
# UP000009136_9913.idmapping
# UP000009136_9913.xml
# UP000015101_6412_DNA.fasta
# UP000015101_6412.fasta
# UP000015101_6412_gcoord.xml
# UP000015101_6412.gene2acc
# UP000015101_6412.idmapping
# UP000015101_6412.xml
# UP000018468_7918_additional.fasta
# UP000018468_7918_DNA.fasta
# UP000018468_7918.fasta
# UP000018468_7918_gcoord.xml
# UP000018468_7918.gene2acc
# UP000018468_7918.idmapping
# UP000018468_7918.xml
# UP000059680_39947_additional.fasta
# UP000059680_39947_DNA.fasta
# UP000059680_39947_DNA.miss
# UP000059680_39947.fasta
# UP000059680_39947.gene2acc
# UP000059680_39947.idmapping
# UP000059680_39947.xml

# %% [markdown]
# ## How much compute is this?

# %% [markdown]
# Number of human transcription factor proteins in the quest for orthologs database

# %%
n_human_qfo_tfs = 5749

# %%
tfs_uniprot_merge_proteins_with_human.head()
# Out:
#      dn_ds     method_link_type        human__id  human__perc_id  \
# 0  0.15000  ENSEMBL_ORTHOLOGUES  ENSG00000101544         96.0212
# 1  0.08163  ENSEMBL_ORTHOLOGUES  ENSG00000101544         99.2927
# 2  0.34381  ENSEMBL_ORTHOLOGUES  ENSG00000101544         58.0018
# 3  0.13859  ENSEMBL_ORTHOLOGUES  ENSG00000101544         78.7798
# 4  0.15195  ENSEMBL_ORTHOLOGUES  ENSG00000101544         80.1061
#
#    human__perc_pos human__protein_id human__species  human__taxon_id  \
# 0          96.1096   ENSP00000262198   homo_sapiens           9606.0
# 1          99.4695   ENSP00000262198   homo_sapiens           9606.0
# 2          71.0875   ENSP00000262198   homo_sapiens           9606.0
# 3          85.9416   ENSP00000262198   homo_sapiens           9606.0
# 4          87.0911   ENSP00000262198   homo_sapiens           9606.0
#
#            target__id  target__perc_id  ...    taxonomy_level  \
# 0  ENSGGOG00000003551          99.6330  ...         Homininae
# 1  ENSPTRG00000010138          99.8222  ...         Homininae
# 2  ENSRNOG00000053843          57.1429  ...  Euarchontoglires
# 3  ENSRNOG00000053370          73.8194  ...  Euarchontoglires
# 4  ENSMUSG00000053950          77.7682  ...  Euarchontoglires
#
#                 type target__uniprot_id  target__id_type       target__db_id  \
# 0   ortholog_one2one             G3QLW5      Ensembl_PRO  ENSGGOP00000003487
# 1   ortholog_one2one             H2QER5      Ensembl_PRO  ENSPTRP00000017225
# 2  ortholog_one2many         A0A0G2K5Q5      Ensembl_PRO  ENSRNOP00000073516
# 3  ortholog_one2many         A0A0G2JT49      Ensembl_PRO  ENSRNOP00000068569
# 4   ortholog_one2one             Q8CHC8      Ensembl_PRO  ENSMUSP00000068560
#
#   target__species_id target__taxa_id human__uniprot_id human__id_type  \
# 0        UP000001519     UP000001519            Q6IQ32    Ensembl_PRO
# 1        UP000002277     UP000002277            Q6IQ32    Ensembl_PRO
# 2        UP000002494     UP000002494            Q6IQ32    Ensembl_PRO
# 3        UP000002494     UP000002494            Q6IQ32    Ensembl_PRO
# 4        UP000000589     UP000000589            Q6IQ32    Ensembl_PRO
#
#       human__db_id
# 0  ENSP00000262198
# 1  ENSP00000262198
# 2  ENSP00000262198
# 3  ENSP00000262198
# 4  ENSP00000262198
#
# [5 rows x 24 columns]

# %%
tfs_uniprot_merge_proteins_with_human.query('target__species != "homo_sapiens"').target__uniprot_id.nunique()
# Out:
# 1045

# %%
n_not_human_qfo_tfs = 1045

# %%
n_human_qfo_tfs * n_not_human_qfo_tfs * 0.0006 / 60 / 60
# Out:
# 1.0012841666666665

# %% [markdown]
# ## Read in protein fastas with screed

# %%
not_human_outdir = 'Eukaryota/not-human-transcription-factor-fastas-random-subset100/'
! mkdir $not_human_outdir


for filename in iglob('Eukaryota/not-human-protein-fastas/*.fasta'):
    tf_records = []

    basename = os.path.basename(filename)
    with screed.open(filename) as records:
        for record in records:
            name = record['name']
            record_id = name.split()[0]
            uniprot_id = record_id.split('|')[1]
            if uniprot_id in tf_orthologs:
                tf_records.append(record)
                
    if len(tf_records) > 0:
        print(filename)
        print(f"\tlen(tf_records): {len(tf_records)}")
        with open(f'{not_human_outdir}/{basename}', 'w') as f:
            for record in tf_records:
                f.write(">{name}\n{sequence}\n".format(**record))
# Out:
# mkdir: cannot create directory ‘Eukaryota/not-human-transcription-factor-fastas-random-subset100/’: File exists
# Eukaryota/not-human-protein-fastas/UP000000437_7955_additional.fasta
# 	len(tf_records): 13
# Eukaryota/not-human-protein-fastas/UP000008143_8364.fasta
# 	len(tf_records): 12
# Eukaryota/not-human-protein-fastas/UP000001038_8090.fasta
# 	len(tf_records): 85
# Eukaryota/not-human-protein-fastas/UP000002280_13616.fasta
# 	len(tf_records): 52
# Eukaryota/not-human-protein-fastas/UP000000539_9031_additional.fasta
# 	len(tf_records): 3
# Eukaryota/not-human-protein-fastas/UP000000803_7227_additional.fasta
# 	len(tf_records): 20
# Eukaryota/not-human-protein-fastas/UP000018468_7918.fasta
# 	len(tf_records): 68
# Eukaryota/not-human-protein-fastas/UP000002254_9615.fasta
# 	len(tf_records): 51
# Eukaryota/not-human-protein-fastas/UP000001940_6239.fasta
# 	len(tf_records): 7
# Eukaryota/not-human-protein-fastas/UP000000437_7955.fasta
# 	len(tf_records): 76
# Eukaryota/not-human-protein-fastas/UP000002311_559292.fasta
# 	len(tf_records): 8
# Eukaryota/not-human-protein-fastas/UP000000589_10090.fasta
# 	len(tf_records): 59
# Eukaryota/not-human-protein-fastas/UP000002254_9615_additional.fasta
# 	len(tf_records): 7
# Eukaryota/not-human-protein-fastas/UP000000803_7227.fasta
# 	len(tf_records): 59
# Eukaryota/not-human-protein-fastas/UP000001519_9595_additional.fasta
# 	len(tf_records): 1
# Eukaryota/not-human-protein-fastas/UP000002494_10116.fasta
# 	len(tf_records): 69
# Eukaryota/not-human-protein-fastas/UP000001519_9595.fasta
# 	len(tf_records): 87
# Eukaryota/not-human-protein-fastas/UP000008143_8364_additional.fasta
# 	len(tf_records): 6
# Eukaryota/not-human-protein-fastas/UP000001940_6239_additional.fasta
# 	len(tf_records): 1
# Eukaryota/not-human-protein-fastas/UP000000539_9031.fasta
# 	len(tf_records): 68
# Eukaryota/not-human-protein-fastas/UP000000589_10090_additional.fasta
# 	len(tf_records): 25
# Eukaryota/not-human-protein-fastas/UP000009136_9913.fasta
# 	len(tf_records): 83
# Eukaryota/not-human-protein-fastas/UP000002277_9598.fasta
# 	len(tf_records): 96
# Eukaryota/not-human-protein-fastas/UP000008144_7719.fasta
# 	len(tf_records): 64
# Eukaryota/not-human-protein-fastas/UP000002494_10116_additional.fasta
# 	len(tf_records): 19
# Eukaryota/not-human-protein-fastas/UP000002277_9598_additional.fasta
# 	len(tf_records): 1
# Eukaryota/not-human-protein-fastas/UP000009136_9913_additional.fasta
# 	len(tf_records): 5

# %% [markdown]
# # Script to run

# %%
# %%file qfo_human_vs_opisthokont_tfs.sh
# #!/bin/bash
# OUTDIR=$HOME/data_sm/kmer-hashing/quest-for-orthologs/analysis/2019/transcription-factors-random-subset100/
# mkdir -p $OUTDIR/intermediates
# cd $OUTDIR/intermediates
#
# PARQUET=$OUTDIR/qfo-eukaryota-tfs-protein.parquet
#
# EUKARYOTA=/mnt/data_sm/olga/kmer-hashing/quest-for-orthologs/data/2019/Eukaryota
# HUMAN=$EUKARYOTA/human-transcription-factor-fastas-random-subset100/human_transcription_factor_proteins.fasta
# NOT_HUMAN=$EUKARYOTA/not-human-transcription-factor-fastas-random-subset100/
#
# conda activate khtools--encodings--compare-cli
#
#
# time khtools compare-kmers \
#     --processes 120 \
#     --ksize-min 3 \
#     --ksize-max 45 \
#     --parquet $PARQUET \
#     --intermediate-parquet \
#     --fastas2 $HUMAN \
#     $NOT_HUMAN/* | tee khtools_compare-kmers.log

# %%
pwd

# %% [markdown]
# ## Time estimation
#
# taking ~1000 seconds per non-human sequence

# %%
n_not_human_qfo_tfs

# %%
n_not_human_qfo_tfs * 1000 / 120 / 60 / 60 / 24

# %% [markdown]
# Okay, so this will take ~4.7 days to compute running on `lrrr`
